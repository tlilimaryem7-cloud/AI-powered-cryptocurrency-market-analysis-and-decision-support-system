# %%
import os

init_path = r"C:\Users\tlili\OneDrive\Bureau\Bootcamp\AI-powered-cryptocurrency-market-analysis-and-decision-support-system\news\__init__.py"

with open(init_path, "w") as f:
    f.write("")

print("✅ __init__.py created in news folder")
# Out:
# ✅ __init__.py created in news folder

# %%
import sys
sys.path.append(r"C:\Users\tlili\OneDrive\Bureau\Bootcamp\AI-powered-cryptocurrency-market-analysis-and-decision-support-system")

from news.tavily_fetcher import fetch_news, format_for_llm

# Test BTC
news = fetch_news("btc")
print(format_for_llm(news))
# Out:
# ...
#   TAVILY NEWS FETCHER — BTC
#   Date : 2026-02-15
# ...
#
#   🔍 Searching BTC news...
#     'Bitcoin BTC price market analysis today' → 5 articles
#     'Bitcoin institutional investors ETF news today' → 5 articles
#     'crypto market sentiment today' → 5 articles
#
#   🔍 Searching macro news...
#     'Federal Reserve interest rates inflation today' → 5 articles
#     'US dollar DXY crypto market impact today' → 5 articles
#     'crypto regulation SEC government news today' → 5 articles
#
#   ✅ Total articles fetched : 30
#      Coin-specific          : 15
#      Macro                  : 15
# RECENT NEWS — BTC (2026-02-15)
# ...
#
# [1] US Dollar Index (DXY) on pace to break 97.00 - MarketPulse
#     Markets Today: Gold Breaches $5100/oz ... fused technicals and fundamentals had an immediate effect on the DXY, down 2.50% until today.
#     Source: https://www.marketpulse.com/markets/us-dollar-index-dxy-breaking-lower/
#
# [2] Crypto Fear and Greed Index Today: 9 (Extreme Fear)
# ...

# %% [markdown]
# Quick insights from today's news:
#
# - Fear & Greed at 9 —> Extreme Fear 😰
# - DXY falling to 4-month low —> historically bullish for BTC
# - ETF inflows of $25.46M on Feb 13 —> institutional interest returning
# - These align perfectly with our ML prediction of UP 70.54%
#
# The pipeline is already making sense —> ML signal + news context tell a consistent story.
